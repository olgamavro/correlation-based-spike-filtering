# %% [markdown]
# # DYNAP-SE1 Excitatory/Inhibitory Network Experiment
#
# This notebook builds a four-population excitatory/inhibitory network on a DYNAP-SE1 device, programs FPGA spike generators, records spikes, and plots the resulting network activity.
#
# **Notebook flow**
# 1. Import packages and connect to the DYNAP-SE1 board.
# 2. Define network connection probabilities.
# 3. Build the excitatory and inhibitory populations.
# 4. Load chip/core parameters.
# 5. Program FPGA spike generators.
# 6. Run the experiment and collect spikes.
# 7. Plot activity and optionally save/reset parameters.

# %%
# =============================================================================
# 1. Imports and setup
# =============================================================================
import os
import subprocess

os.environ["LIBGL_ALWAYS_INDIRECT"] = "1"

import sys
import time
import importlib

import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image

# Project-specific utilities. The parent directory contains helper modules.
sys.path.append('..')

import samna
import samna.dynapse1 as dyn1
import dynapse1utils as ut
import params

from netgen import Neuron, NetworkGenerator
from params import set_params

# %%
# =============================================================================
# 2. Connect to the DYNAP-SE1 board
# =============================================================================

# Open the DYNAP-SE1 board and retrieve a Dynapse1Model instance.
#
# The specific-device utility is used here because remote setups such as Zemo
# may expose more than one attached board. Change `device_id` if a different
# board should be selected.
#model, _ = ut.open_specific_device_in_sequence(device_id=1)

# alternative:
model, _ = ut.open_dynapse1(gui=False)
# Out:
# ERROR: Address already in use, please re-run open_device()!
# [0]:  Bus 1 Device 2 Dynapse1DevKit serial_number 00000033
# 0 Dynapse1Wrapper created! libcaer init...
# Selected device: 00000033
# Sender port: tcp://0.0.0.0:58535
# Receiver port: tcp://0.0.0.0:56359
# Opened device name: Dynapse1DevKit
# SamnaNode ID: 1
# PythonNode ID: 2
# Clearing chip 0... DONE.
# Clearing chip 1... DONE.
# Clearing chip 2... DONE.
# Clearing chip 3... DONE.

# %%
api = model.get_dynapse1_api()

CHIP_ID = 0
E_CORE_ID =0
I_CORE_ID = 2
CORE_CAPACITY = 256

# %%
HUN = True
BASIC_PARAMS = False
EX_INDIVIDUAL_PARAMS = False
IN_INDIVIDUAL_PARAMS = False
PERFECT = False
REFERENCE = True
MATCH_TO = 0
PARAMS_SAVE = False

# %%
# =============================================================================
# 3. Load neuron and synapse parameters
# =============================================================================
# Option B: load parameters from a text file/profile.
# The profile name below should match the parameter file expected by the helper.
if HUN == True:
    ut.set_parameters_in_txt_file(model, 'hun')
    time.sleep(2)  # Short delay to ensure parameters are set before proceeding.


# Option A: use the parameter-setting helper from params.py.
# Uncomment if this is the preferred parameter source.
if BASIC_PARAMS == True:
    set_params(model)


if PERFECT == True:
    ut.set_parameters_in_txt_file(model, 'working_both')

# %%
# =============================================================================
# 4. Network connection probabilities
# =============================================================================

# Probability of excitatory-to-excitatory recurrent connections.
p_E_E = 0.9

# Probability of excitatory-to-inhibitory feedforward connections.
p_E_I = 0.5

# Probability of inhibitory-to-excitatory feedback/cross-population connections.
p_I_E = 0.7

# Probability of inhibitory-to-inhibitory recurrent connections.
p_I_I = 0.2

# Probability of input channel to excitatory connections.
p_C_E = 1.0

# Probability of reference to excitatory connections.
if REFERENCE == True:    
    p_R_E = 1.0
else:    p_R_E = 0.0

# %%
if PARAMS_SAVE == True:
    ut.save_parameters2txt_file(model.get_configuration(), 'buffer_params.txt')

# %%
# -------------------------------------------------------------------------
# Population definitions (blob/square placement on 16x16 core)
# Compact square "blobs" per population — no avoids
# -------------------------------------------------------------------------
import math
# =============================================================================
# 5. Build and apply the E/I network configuration
# =============================================================================

# Reload parameter helper module so notebook edits are picked up without
# restarting the kernel.
importlib.reload(params)

serial_number = ut.get_serial_number()
print("Serial number:", serial_number)

# Create a fresh network generator.
net_gen = NetworkGenerator()
net_gen.clear_network()

# -----------------------------------------------------------------------------
# Spike generators
# -----------------------------------------------------------------------------
# Five virtual neurons are used as FPGA spike-generator sources.
# The first four drive the four excitatory populations. The fifth is reserved
# as a reference generator in the FPGA programming cell.

spikegen_ids = [
    (0, 1, 15),
    (0, 1, 16),
    (0, 1, 17),
    (0, 1, 18),
    (0, 1, 19),
]
spikegens = [Neuron(chip, core, neuron, True) for chip, core, neuron in spikegen_ids]

# population sizes (keep your existing values)
N_EXC_PER_POP = 16
N_INH_PER_POP = 16
N_POPULATIONS = 4

# core/grid parameters
GRID_SIDE = 16  # 16x16 neurons per core

def pos_to_id(x, y, grid=GRID_SIDE):
    return int(y) * grid + int(x)

def id_to_pos(nid, grid=GRID_SIDE):
    return (nid % grid, nid // grid)

def tile_center(pop_index, n_pops, grid=GRID_SIDE):
    tiles = int(math.ceil(math.sqrt(max(1, n_pops))))
    tx = pop_index % tiles
    ty = pop_index // tiles
    tile_w = grid / tiles
    cx = int(round(tx * tile_w + tile_w / 2 - 0.5))
    cy = int(round(ty * tile_w + tile_w / 2 - 0.5))
    cx = max(0, min(grid-1, cx))
    cy = max(0, min(grid-1, cy))
    return cx, cy

def square_blob_ids(center, n_neurons, grid=GRID_SIDE):
    cx, cy = center
    side = int(math.ceil(math.sqrt(n_neurons)))
    x0 = cx - side // 2
    y0 = cy - side // 2
    candidates = []
    for y in range(y0, y0 + side):
        for x in range(x0, x0 + side):
            if 0 <= x < grid and 0 <= y < grid:
                candidates.append((x, y))
    picked = []
    used = set()
    for x, y in candidates:
        picked.append((x, y)); used.add((x,y))
        if len(picked) >= n_neurons:
            break
    if len(picked) < n_neurons:
        all_cells = [(x, y, math.hypot(x-cx, y-cy)) for y in range(grid) for x in range(grid)]
        all_cells.sort(key=lambda t: (t[2], t[1], t[0]))
        for x, y, _ in all_cells:
            if (x,y) in used:
                continue
            picked.append((x,y)); used.add((x,y))
            if len(picked) >= n_neurons:
                break
    return [pos_to_id(x,y,grid) for x,y in picked[:n_neurons]]

def make_square_populations(chip_id, core_id, n_pops, per_pop, grid=GRID_SIDE):
    pops = []
    for pidx in range(n_pops):
        center = tile_center(pidx, n_pops, grid)
        ids = square_blob_ids(center, per_pop, grid=grid)
        pops.append([(chip_id, core_id, int(nid)) for nid in ids])
    return pops

# Create populations (replaces exc_neuron_ids / inh_neuron_ids construction)
exc_neuron_ids = make_square_populations(CHIP_ID, E_CORE_ID, N_POPULATIONS, N_EXC_PER_POP)
inh_neuron_ids = make_square_populations(CHIP_ID, I_CORE_ID, N_POPULATIONS, N_INH_PER_POP)

exc_neuron_ids[1][8]=(0, 0, 28) 
exc_neuron_ids[1][2]=(0, 0, 29)

inh_neuron_ids[0][1]=(0, 2, 18)
inh_neuron_ids[0][6]=(0, 2, 19) 
inh_neuron_ids[0][15]=(0, 2, 21)

inh_neuron_ids[1][15]=(0, 2, 94)

inh_neuron_ids[2][14]=(0, 2, 226)
inh_neuron_ids[2][0]=(0, 2, 161)
inh_neuron_ids[2][1]=(0, 2, 177) 
inh_neuron_ids[2][6]=(0, 2, 193)
inh_neuron_ids[2][11]=(0, 2, 209)

inh_neuron_ids[3][2]=(0, 2, 174)

# Optional: print and quick visual check (uncomment to view)
print("Excitatory neuron ids:", exc_neuron_ids)
print("Inhibitory neuron ids:", inh_neuron_ids)

# Convert to Neuron objects (keep original naming)
exc_neurons = [[Neuron(chip, core, neuron) for chip, core, neuron in population] for population in exc_neuron_ids]
inh_neurons = [[Neuron(chip, core, neuron) for chip, core, neuron in population] for population in inh_neuron_ids]



# Keep the original variable names for compatibility with later notebook cells.
#exc_neuron_ids_1, exc_neuron_ids_2, exc_neuron_ids_3, exc_neuron_ids_4 = exc_neuron_ids
#exc_neurons_1, exc_neurons_2, exc_neurons_3, exc_neurons_4 = exc_neurons
#inh_neuron_ids_1, inh_neuron_ids_2, inh_neuron_ids_3, inh_neuron_ids_4 = inh_neuron_ids
#inh_neurons_1, inh_neurons_2, inh_neurons_3, inh_neurons_4 = inh_neurons

# -----------------------------------------------------------------------------
# Excitatory populations: input drive + recurrent E->E connectivity
# -----------------------------------------------------------------------------
for pop_index, population in enumerate(exc_neurons):
    input_generator = spikegens[pop_index]

    for pre_index, pre_neuron in enumerate(population):
        # Connect the population-specific FPGA spike generator to each
        # excitatory neuron using slow excitatory AMPA synapses.
        if np.random.uniform() < p_C_E:
            net_gen.add_connection(input_generator, pre_neuron, dyn1.Dynapse1SynType.AMPA)

        # Add recurrent E->E connections within the same population.
        for post_index, post_neuron in enumerate(population):
            if pre_index != post_index and np.random.uniform() < p_E_E:
                net_gen.add_connection(pre_neuron, post_neuron, dyn1.Dynapse1SynType.NMDA)

# -----------------------------------------------------------------------------
# Inhibitory populations: recurrent I->I connectivity
# -----------------------------------------------------------------------------
for population in inh_neurons:
    for pre_index, pre_neuron in enumerate(population):
        for post_index, post_neuron in enumerate(population):
            if pre_index != post_index and np.random.uniform() < p_I_I:
                net_gen.add_connection(pre_neuron, post_neuron, dyn1.Dynapse1SynType.GABA_A)

# -----------------------------------------------------------------------------
# Excitatory-to-inhibitory connections within matching populations
# -----------------------------------------------------------------------------
for pop_index in range(N_POPULATIONS):
    for exc_neuron in exc_neurons[pop_index]:
        for inh_neuron in inh_neurons[pop_index]:
            if np.random.uniform() < p_E_I:
                net_gen.add_connection(exc_neuron, inh_neuron, dyn1.Dynapse1SynType.AMPA)

# -----------------------------------------------------------------------------
# Inhibitory-to-excitatory cross-population connections
# -----------------------------------------------------------------------------
# Inhibition from population i targets excitatory neurons in all other
# populations h != i using slow inhibitory GABA_B synapses.
for inh_pop_index in range(N_POPULATIONS):
    for exc_pop_index in range(N_POPULATIONS):
        if inh_pop_index == exc_pop_index:
            continue

        for inh_neuron in inh_neurons[inh_pop_index]:
            for exc_neuron in exc_neurons[exc_pop_index]:
                if np.random.uniform() < p_I_E:
                    net_gen.add_connection(inh_neuron, exc_neuron, dyn1.Dynapse1SynType.GABA_B)

# -----------------------------------------------------------------------------
# Reference generator -> all excitatory populations
# -----------------------------------------------------------------------------
# Connect the last spike generator (reference) to every excitatory neuron
if len(spikegens) > N_POPULATIONS:
    ref_gen = spikegens[N_POPULATIONS]
    for population in exc_neurons:
        for neuron in population:
            if np.random.uniform() < p_R_E:
                net_gen.add_connection(ref_gen, neuron, dyn1.Dynapse1SynType.NMDA)
else:
    print('Warning: reference spike generator (spikegens[N_POPULATIONS]) not available; no reference connections added')

# Review the generated network before applying it.
print(net_gen.network)

# Convert the generated network into a DYNAP-SE1 configuration and apply it.
new_config = net_gen.make_dynapse1_configuration()
model.apply_configuration(new_config)
# Out:
# Serial number: 00000033
# Excitatory neuron ids: [[(0, 0, 34), (0, 0, 35), (0, 0, 36), (0, 0, 37), (0, 0, 50), (0, 0, 51), (0, 0, 52), (0, 0, 53), (0, 0, 66), (0, 0, 67), (0, 0, 68), (0, 0, 69), (0, 0, 82), (0, 0, 83), (0, 0, 84), (0, 0, 85)], [(0, 0, 42), (0, 0, 43), (0, 0, 29), (0, 0, 45), (0, 0, 58), (0, 0, 59), (0, 0, 60), (0, 0, 61), (0, 0, 28), (0, 0, 75), (0, 0, 76), (0, 0, 77), (0, 0, 90), (0, 0, 91), (0, 0, 92), (0, 0, 93)], [(0, 0, 162), (0, 0, 163), (0, 0, 164), (0, 0, 165), (0, 0, 178), (0, 0, 179), (0, 0, 180), (0, 0, 181), (0, 0, 194), (0, 0, 195), (0, 0, 196), (0, 0, 197), (0, 0, 210), (0, 0, 211), (0, 0, 212), (0, 0, 213)], [(0, 0, 170), (0, 0, 171), (0, 0, 172), (0, 0, 173), (0, 0, 186), (0, 0, 187), (0, 0, 188), (0, 0, 189), (0, 0, 202), (0, 0, 203), (0, 0, 204), (0, 0, 205), (0, 0, 218), (0, 0, 219), (0, 0, 220), (0, 0, 221)]]
# Inhibitory neuron ids: [[(0, 2, 34), (0, 2, 18), (0, 2, 36), (0, 2, 37), (0, 2, 50), (0, 2, 51), (0, 2, 19), (0, 2, 53), (0, 2, 66), (0, 2, 67), (0, 2, 68), (0, 2, 69), (0, 2, 82), (0, 2, 83), (0, 2, 84), (0, 2, 21)], [(0, 2, 42), (0, 2, 43), (0, 2, 44), (0, 2, 45), (0, 2, 58), (0, 2, 59), (0, 2, 60), (0, 2, 61), (0, 2, 74), (0, 2, 75), (0, 2, 76), (0, 2, 77), (0, 2, 90), (0, 2, 91), (0, 2, 92), (0, 2, 94)], [(0, 2, 161), (0, 2, 177), (0, 2, 164), (0, 2, 165), (0, 2, 178), (0, 2, 179), (0, 2, 193), (0, 2, 181), (0, 2, 194), (0, 2, 195), (0, 2, 196), (0, 2, 209), (0, 2, 210), (0, 2, 211), (0, 2, 226), (0, 2, 213)], [(0, 2, 170), (0, 2, 171), (0, 2, 174), (0, 2, 173), (0, 2, 186), (0, 2, 187), (0, 2, 188), (0, 2, 189), (0, 2, 202), (0, 2, 203), (0, 2, 204), (0, 2, 205), (0, 2, 218), (0, 2, 219), (0, 2, 220), (0, 2, 221)]]
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c0n34: [('C0c1s15', 'AMPA'), ('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n42', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n35: [('C0c0n34', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n36: [('C0c0n34', 'NMDA'), ('C0c0n35', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n37', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n37: [('C0c0n34', 'NMDA'), ('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n42', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n53: [('C0c0n34', 'NMDA'), ('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n43', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n67: [('C0c0n34', 'NMDA'), ('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n68: [('C0c0n34', 'NMDA'), ('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n69: [('C0c0n34', 'NMDA'), ('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n82: [('C0c0n34', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n83: [('C0c0n34', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n85', 'NMDA'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n85: [('C0c0n34', 'NMDA'), ('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n50: [('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n44', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n51: [('C0c0n35', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n66: [('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n84: [('C0c0n35', 'NMDA'), ('C0c0n36', 'NMDA'), ('C0c0n37', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c0n52', 'NMDA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n85', 'NMDA'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n52: [('C0c0n36', 'NMDA'), ('C0c0n50', 'NMDA'), ('C0c0n51', 'NMDA'), ('C0c1s15', 'AMPA'), ('C0c0n53', 'NMDA'), ('C0c0n66', 'NMDA'), ('C0c0n67', 'NMDA'), ('C0c0n68', 'NMDA'), ('C0c0n69', 'NMDA'), ('C0c0n82', 'NMDA'), ('C0c0n83', 'NMDA'), ('C0c0n84', 'NMDA'), ('C0c0n85', 'NMDA'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n42: [('C0c1s16', 'AMPA'), ('C0c0n43', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n29: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n45: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n58: [('C0c0n42', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n59', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n18', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n59: [('C0c0n42', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n60: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n18', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n61: [('C0c0n42', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n28: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n76: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n18', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n77: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n90: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n91: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n92: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n93: [('C0c0n42', 'NMDA'), ('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n77', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n178', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n43: [('C0c1s16', 'AMPA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c0n75', 'NMDA'), ('C0c0n76', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n213', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n75: [('C0c0n43', 'NMDA'), ('C0c0n29', 'NMDA'), ('C0c0n45', 'NMDA'), ('C0c0n58', 'NMDA'), ('C0c0n59', 'NMDA'), ('C0c0n60', 'NMDA'), ('C0c0n61', 'NMDA'), ('C0c0n28', 'NMDA'), ('C0c1s16', 'AMPA'), ('C0c0n76', 'NMDA'), ('C0c0n90', 'NMDA'), ('C0c0n91', 'NMDA'), ('C0c0n92', 'NMDA'), ('C0c0n93', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n161', 'GABA_B'), ('C0c2n177', 'GABA_B'), ('C0c2n164', 'GABA_B'), ('C0c2n165', 'GABA_B'), ('C0c2n179', 'GABA_B'), ('C0c2n193', 'GABA_B'), ('C0c2n181', 'GABA_B'), ('C0c2n194', 'GABA_B'), ('C0c2n195', 'GABA_B'), ('C0c2n196', 'GABA_B'), ('C0c2n209', 'GABA_B'), ('C0c2n210', 'GABA_B'), ('C0c2n211', 'GABA_B'), ('C0c2n226', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n162: [('C0c1s17', 'AMPA'), ('C0c0n163', 'NMDA'), ('C0c0n164', 'NMDA'), ('C0c0n165', 'NMDA'), ('C0c0n178', 'NMDA'), ('C0c0n179', 'NMDA'), ('C0c0n180', 'NMDA'), ('C0c0n181', 'NMDA'), ('C0c0n194', 'NMDA'), ('C0c0n196', 'NMDA'), ('C0c0n197', 'NMDA'), ('C0c0n210', 'NMDA'), ('C0c0n211', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n163: [('C0c0n162', 'NMDA'), ('C0c1s17', 'AMPA'), ('C0c0n164', 'NMDA'), ('C0c0n165', 'NMDA'), ('C0c0n178', 'NMDA'), ('C0c0n179', 'NMDA'), ('C0c0n180', 'NMDA'), ('C0c0n181', 'NMDA'), ('C0c0n194', 'NMDA'), ('C0c0n195', 'NMDA'), ('C0c0n196', 'NMDA'), ('C0c0n197', 'NMDA'), ('C0c0n211', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n164: [('C0c0n162', 'NMDA'), ('C0c0n163', 'NMDA'), ('C0c1s17', 'AMPA'), ('C0c0n178', 'NMDA'), ('C0c0n179', 'NMDA'), ('C0c0n180', 'NMDA'), ('C0c0n181', 'NMDA'), ('C0c0n195', 'NMDA'), ('C0c0n196', 'NMDA'), ('C0c0n197', 'NMDA'), ('C0c0n210', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n165: [('C0c0n162', 'NMDA'), ('C0c0n163', 'NMDA'), ('C0c0n164', 'NMDA'), ('C0c1s17', 'AMPA'), ('C0c0n178', 'NMDA'), ('C0c0n179', 'NMDA'), ('C0c0n181', 'NMDA'), ('C0c0n194', 'NMDA'), ('C0c0n195', 'NMDA'), ('C0c0n196', 'NMDA'), ('C0c0n197', 'NMDA'), ('C0c0n210', 'NMDA'), ('C0c0n211', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n42', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n178: [('C0c0n162', 'NMDA'), ('C0c0n163', 'NMDA'), ('C0c0n164', 'NMDA'), ('C0c0n165', 'NMDA'), ('C0c1s17', 'AMPA'), ('C0c0n179', 'NMDA'), ('C0c0n180', 'NMDA'), ('C0c0n181', 'NMDA'), ('C0c0n194', 'NMDA'), ('C0c0n195', 'NMDA'), ('C0c0n196', 'NMDA'), ('C0c0n197', 'NMDA'), ('C0c0n210', 'NMDA'), ('C0c0n211', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n179: [('C0c0n162', 'NMDA'), ('C0c0n163', 'NMDA'), ('C0c0n164', 'NMDA'), ('C0c0n165', 'NMDA'), ('C0c0n178', 'NMDA'), ('C0c1s17', 'AMPA'), ('C0c0n194', 'NMDA'), ('C0c0n195', 'NMDA'), ('C0c0n196', 'NMDA'), ('C0c0n210', 'NMDA'), ('C0c0n211', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n18', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n50', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n42', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n181: [('C0c0n162', 'NMDA'), ('C0c0n163', 'NMDA'), ('C0c0n164', 'NMDA'), ('C0c0n165', 'NMDA'), ('C0c0n178', 'NMDA'), ('C0c0n179', 'NMDA'), ('C0c0n180', 'NMDA'), ('C0c1s17', 'AMPA'), ('C0c0n194', 'NMDA'), ('C0c0n196', 'NMDA'), ('C0c0n210', 'NMDA'), ('C0c0n211', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n36', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n205', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n194: [('C0c0n162', 'NMDA'), ('C0c0n163', 'NMDA'), ('C0c0n164', 'NMDA'), ('C0c0n165', 'NMDA'), ('C0c0n178', 'NMDA'), ('C0c0n179', 'NMDA'), ('C0c0n180', 'NMDA'), ('C0c0n181', 'NMDA'), ('C0c1s17', 'AMPA'), ('C0c0n195', 'NMDA'), ('C0c0n196', 'NMDA'), ('C0c0n210', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n18', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n66', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n75', 'GABA_B'), ('C0c2n76', 'GABA_B'), ('C0c2n77', 'GABA_B'), ('C0c2n90', 'GABA_B'), ('C0c2n91', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n173', 'GABA_B'), ('C0c2n186', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n189', 'GABA_B'), ('C0c2n202', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n219', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c2n221', 'GABA_B'), ('C0c1s19', 'NMDA')]
# C0c0n195: [('C0c0n162', 'NMDA'), ('C0c0n163', 'NMDA'), ('C0c0n164', 'NMDA'), ('C0c0n165', 'NMDA'), ('C0c0n178', 'NMDA'), ('C0c0n179', 'NMDA'), ('C0c0n180', 'NMDA'), ('C0c0n181', 'NMDA'), ('C0c0n194', 'NMDA'), ('C0c1s17', 'AMPA'), ('C0c0n196', 'NMDA'), ('C0c0n210', 'NMDA'), ('C0c0n211', 'NMDA'), ('C0c0n212', 'NMDA'), ('C0c0n213', 'NMDA'), ('C0c2n34', 'GABA_B'), ('C0c2n37', 'GABA_B'), ('C0c2n51', 'GABA_B'), ('C0c2n19', 'GABA_B'), ('C0c2n53', 'GABA_B'), ('C0c2n67', 'GABA_B'), ('C0c2n68', 'GABA_B'), ('C0c2n69', 'GABA_B'), ('C0c2n82', 'GABA_B'), ('C0c2n83', 'GABA_B'), ('C0c2n84', 'GABA_B'), ('C0c2n21', 'GABA_B'), ('C0c2n42', 'GABA_B'), ('C0c2n43', 'GABA_B'), ('C0c2n44', 'GABA_B'), ('C0c2n45', 'GABA_B'), ('C0c2n58', 'GABA_B'), ('C0c2n59', 'GABA_B'), ('C0c2n60', 'GABA_B'), ('C0c2n61', 'GABA_B'), ('C0c2n74', 'GABA_B'), ('C0c2n92', 'GABA_B'), ('C0c2n94', 'GABA_B'), ('C0c2n170', 'GABA_B'), ('C0c2n171', 'GABA_B'), ('C0c2n174', 'GABA_B'), ('C0c2n187', 'GABA_B'), ('C0c2n188', 'GABA_B'), ('C0c2n203', 'GABA_B'), ('C0c2n204', 'GABA_B'), ('C0c2n218', 'GABA_B'), ('C0c2n220', 'GABA_B'), ('C0c1s19', 'NMDA')]
# ...
# C0c2n19: [('C0c2n18', 'GABA_A'), ('C0c2n50', 'GABA_A'), ('C0c2n51', 'GABA_A'), ('C0c2n53', 'GABA_A'), ('C0c2n82', 'GABA_A'), ('C0c2n83', 'GABA_A'), ('C0c0n34', 'AMPA'), ('C0c0n35', 'AMPA'), ('C0c0n36', 'AMPA'), ('C0c0n37', 'AMPA'), ('C0c0n50', 'AMPA'), ('C0c0n51', 'AMPA'), ('C0c0n68', 'AMPA'), ('C0c0n69', 'AMPA'), ('C0c0n82', 'AMPA')]
# C0c2n21: [('C0c2n18', 'GABA_A'), ('C0c2n84', 'GABA_A'), ('C0c0n34', 'AMPA'), ('C0c0n35', 'AMPA'), ('C0c0n51', 'AMPA'), ('C0c0n52', 'AMPA'), ('C0c0n53', 'AMPA'), ('C0c0n66', 'AMPA'), ('C0c0n68', 'AMPA'), ('C0c0n69', 'AMPA'), ('C0c0n82', 'AMPA'), ('C0c0n83', 'AMPA')]
# C0c2n82: [('C0c2n36', 'GABA_A'), ('C0c2n68', 'GABA_A'), ('C0c0n36', 'AMPA'), ('C0c0n50', 'AMPA'), ('C0c0n51', 'AMPA'), ('C0c0n67', 'AMPA'), ('C0c0n69', 'AMPA'), ('C0c0n82', 'AMPA'), ('C0c0n83', 'AMPA'), ('C0c0n84', 'AMPA'), ('C0c0n85', 'AMPA')]
# C0c2n83: [('C0c2n36', 'GABA_A'), ('C0c2n19', 'GABA_A'), ('C0c2n66', 'GABA_A'), ('C0c2n68', 'GABA_A'), ('C0c2n84', 'GABA_A'), ('C0c0n34', 'AMPA'), ('C0c0n36', 'AMPA'), ('C0c0n37', 'AMPA'), ('C0c0n50', 'AMPA'), ('C0c0n51', 'AMPA'), ('C0c0n52', 'AMPA'), ('C0c0n53', 'AMPA'), ('C0c0n66', 'AMPA'), ('C0c0n82', 'AMPA'), ('C0c0n83', 'AMPA'), ('C0c0n85', 'AMPA')]
# C0c2n69: [('C0c2n37', 'GABA_A'), ('C0c2n50', 'GABA_A'), ('C0c2n51', 'GABA_A'), ('C0c2n19', 'GABA_A'), ('C0c2n53', 'GABA_A'), ('C0c2n66', 'GABA_A'), ('C0c2n82', 'GABA_A'), ('C0c2n84', 'GABA_A'), ('C0c0n34', 'AMPA'), ('C0c0n35', 'AMPA'), ('C0c0n36', 'AMPA'), ('C0c0n52', 'AMPA'), ('C0c0n66', 'AMPA'), ('C0c0n67', 'AMPA'), ('C0c0n69', 'AMPA'), ('C0c0n84', 'AMPA'), ('C0c0n85', 'AMPA')]
# C0c2n36: [('C0c2n50', 'GABA_A'), ('C0c2n66', 'GABA_A'), ('C0c2n69', 'GABA_A'), ('C0c0n35', 'AMPA'), ('C0c0n37', 'AMPA'), ('C0c0n51', 'AMPA'), ('C0c0n82', 'AMPA'), ('C0c0n84', 'AMPA')]
# C0c2n51: [('C0c2n50', 'GABA_A'), ('C0c2n19', 'GABA_A'), ('C0c0n34', 'AMPA'), ('C0c0n36', 'AMPA'), ('C0c0n50', 'AMPA'), ('C0c0n52', 'AMPA'), ('C0c0n53', 'AMPA'), ('C0c0n66', 'AMPA'), ('C0c0n67', 'AMPA'), ('C0c0n82', 'AMPA'), ('C0c0n83', 'AMPA'), ('C0c0n84', 'AMPA'), ('C0c0n85', 'AMPA')]
# C0c2n84: [('C0c2n50', 'GABA_A'), ('C0c0n36', 'AMPA'), ('C0c0n50', 'AMPA'), ('C0c0n51', 'AMPA'), ('C0c0n52', 'AMPA'), ('C0c0n53', 'AMPA'), ('C0c0n66', 'AMPA'), ('C0c0n83', 'AMPA')]
# C0c2n37: [('C0c2n19', 'GABA_A'), ('C0c2n67', 'GABA_A'), ('C0c2n84', 'GABA_A'), ('C0c0n35', 'AMPA'), ('C0c0n36', 'AMPA'), ('C0c0n51', 'AMPA'), ('C0c0n67', 'AMPA'), ('C0c0n82', 'AMPA'), ('C0c0n84', 'AMPA'), ('C0c0n85', 'AMPA')]
# C0c2n66: [('C0c2n19', 'GABA_A'), ('C0c2n84', 'GABA_A'), ('C0c0n36', 'AMPA'), ('C0c0n37', 'AMPA'), ('C0c0n50', 'AMPA'), ('C0c0n52', 'AMPA'), ('C0c0n67', 'AMPA'), ('C0c0n69', 'AMPA'), ('C0c0n82', 'AMPA'), ('C0c0n83', 'AMPA'), ('C0c0n84', 'AMPA'), ('C0c0n85', 'AMPA')]
# C0c2n67: [('C0c2n66', 'GABA_A'), ('C0c0n35', 'AMPA'), ('C0c0n37', 'AMPA'), ('C0c0n52', 'AMPA'), ('C0c0n66', 'AMPA'), ('C0c0n69', 'AMPA'), ('C0c0n83', 'AMPA')]
# C0c2n34: [('C0c2n67', 'GABA_A'), ('C0c2n83', 'GABA_A'), ('C0c0n35', 'AMPA'), ('C0c0n36', 'AMPA'), ('C0c0n37', 'AMPA'), ('C0c0n53', 'AMPA'), ('C0c0n66', 'AMPA'), ('C0c0n69', 'AMPA'), ('C0c0n82', 'AMPA')]
# C0c2n50: [('C0c2n67', 'GABA_A'), ('C0c2n82', 'GABA_A'), ('C0c2n21', 'GABA_A'), ('C0c0n34', 'AMPA'), ('C0c0n35', 'AMPA'), ('C0c0n36', 'AMPA'), ('C0c0n51', 'AMPA'), ('C0c0n66', 'AMPA'), ('C0c0n69', 'AMPA'), ('C0c0n82', 'AMPA'), ('C0c0n84', 'AMPA')]
# C0c2n45: [('C0c2n42', 'GABA_A'), ('C0c2n58', 'GABA_A'), ('C0c2n60', 'GABA_A'), ('C0c2n76', 'GABA_A'), ('C0c2n90', 'GABA_A'), ('C0c2n91', 'GABA_A'), ('C0c0n43', 'AMPA'), ('C0c0n29', 'AMPA'), ('C0c0n45', 'AMPA'), ('C0c0n58', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n93', 'AMPA')]
# C0c2n91: [('C0c2n43', 'GABA_A'), ('C0c2n61', 'GABA_A'), ('C0c2n90', 'GABA_A'), ('C0c0n42', 'AMPA'), ('C0c0n43', 'AMPA'), ('C0c0n29', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n77', 'AMPA')]
# C0c2n43: [('C0c2n44', 'GABA_A'), ('C0c2n61', 'GABA_A'), ('C0c2n74', 'GABA_A'), ('C0c2n92', 'GABA_A'), ('C0c0n42', 'AMPA'), ('C0c0n43', 'AMPA'), ('C0c0n29', 'AMPA'), ('C0c0n45', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n60', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n92', 'AMPA'), ('C0c0n93', 'AMPA')]
# C0c2n61: [('C0c2n44', 'GABA_A'), ('C0c2n60', 'GABA_A'), ('C0c2n91', 'GABA_A'), ('C0c0n43', 'AMPA'), ('C0c0n58', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n93', 'AMPA')]
# C0c2n74: [('C0c2n44', 'GABA_A'), ('C0c2n45', 'GABA_A'), ('C0c2n76', 'GABA_A'), ('C0c2n92', 'GABA_A'), ('C0c0n60', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n77', 'AMPA'), ('C0c0n91', 'AMPA'), ('C0c0n92', 'AMPA'), ('C0c0n93', 'AMPA')]
# C0c2n75: [('C0c2n44', 'GABA_A'), ('C0c2n60', 'GABA_A'), ('C0c2n76', 'GABA_A'), ('C0c2n90', 'GABA_A'), ('C0c2n91', 'GABA_A'), ('C0c0n42', 'AMPA'), ('C0c0n45', 'AMPA'), ('C0c0n58', 'AMPA'), ('C0c0n60', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n76', 'AMPA')]
# C0c2n77: [('C0c2n44', 'GABA_A'), ('C0c2n92', 'GABA_A'), ('C0c0n42', 'AMPA'), ('C0c0n43', 'AMPA'), ('C0c0n45', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n60', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n77', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n91', 'AMPA'), ('C0c0n93', 'AMPA')]
# C0c2n94: [('C0c2n44', 'GABA_A'), ('C0c2n75', 'GABA_A'), ('C0c2n91', 'GABA_A'), ('C0c0n42', 'AMPA'), ('C0c0n29', 'AMPA'), ('C0c0n45', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n91', 'AMPA')]
# C0c2n90: [('C0c2n45', 'GABA_A'), ('C0c2n60', 'GABA_A'), ('C0c2n91', 'GABA_A'), ('C0c0n29', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n77', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n92', 'AMPA'), ('C0c0n93', 'AMPA')]
# C0c2n92: [('C0c2n45', 'GABA_A'), ('C0c2n75', 'GABA_A'), ('C0c2n77', 'GABA_A'), ('C0c0n43', 'AMPA'), ('C0c0n29', 'AMPA'), ('C0c0n45', 'AMPA'), ('C0c0n58', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n60', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n77', 'AMPA')]
# C0c2n59: [('C0c2n58', 'GABA_A'), ('C0c2n74', 'GABA_A'), ('C0c2n76', 'GABA_A'), ('C0c2n90', 'GABA_A'), ('C0c2n94', 'GABA_A'), ('C0c0n43', 'AMPA'), ('C0c0n29', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n77', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n92', 'AMPA'), ('C0c0n93', 'AMPA')]
# C0c2n42: [('C0c2n59', 'GABA_A'), ('C0c2n92', 'GABA_A'), ('C0c0n42', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n60', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n90', 'AMPA')]
# C0c2n76: [('C0c2n60', 'GABA_A'), ('C0c2n61', 'GABA_A'), ('C0c2n92', 'GABA_A'), ('C0c0n29', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n77', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n93', 'AMPA')]
# C0c2n58: [('C0c2n75', 'GABA_A'), ('C0c2n76', 'GABA_A'), ('C0c2n91', 'GABA_A'), ('C0c2n94', 'GABA_A'), ('C0c0n43', 'AMPA'), ('C0c0n29', 'AMPA'), ('C0c0n45', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n28', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n77', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n91', 'AMPA'), ('C0c0n92', 'AMPA')]
# C0c2n60: [('C0c2n76', 'GABA_A'), ('C0c2n94', 'GABA_A'), ('C0c0n42', 'AMPA'), ('C0c0n45', 'AMPA'), ('C0c0n60', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n77', 'AMPA'), ('C0c0n90', 'AMPA'), ('C0c0n91', 'AMPA'), ('C0c0n92', 'AMPA')]
# C0c2n177: [('C0c2n161', 'GABA_A'), ('C0c2n164', 'GABA_A'), ('C0c2n178', 'GABA_A'), ('C0c2n196', 'GABA_A'), ('C0c2n209', 'GABA_A'), ('C0c2n226', 'GABA_A'), ('C0c2n213', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n163', 'AMPA'), ('C0c0n164', 'AMPA'), ('C0c0n165', 'AMPA'), ('C0c0n178', 'AMPA'), ('C0c0n194', 'AMPA'), ('C0c0n210', 'AMPA'), ('C0c0n211', 'AMPA'), ('C0c0n212', 'AMPA')]
# C0c2n179: [('C0c2n177', 'GABA_A'), ('C0c2n181', 'GABA_A'), ('C0c2n209', 'GABA_A'), ('C0c2n226', 'GABA_A'), ('C0c0n179', 'AMPA'), ('C0c0n181', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n196', 'AMPA'), ('C0c0n212', 'AMPA'), ('C0c0n213', 'AMPA')]
# C0c2n194: [('C0c2n177', 'GABA_A'), ('C0c2n165', 'GABA_A'), ('C0c2n178', 'GABA_A'), ('C0c2n196', 'GABA_A'), ('C0c2n210', 'GABA_A'), ('C0c2n211', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n164', 'AMPA'), ('C0c0n165', 'AMPA'), ('C0c0n178', 'AMPA'), ('C0c0n179', 'AMPA'), ('C0c0n180', 'AMPA'), ('C0c0n181', 'AMPA'), ('C0c0n211', 'AMPA')]
# C0c2n196: [('C0c2n177', 'GABA_A'), ('C0c2n164', 'GABA_A'), ('C0c2n178', 'GABA_A'), ('C0c2n179', 'GABA_A'), ('C0c2n193', 'GABA_A'), ('C0c2n194', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n164', 'AMPA'), ('C0c0n165', 'AMPA'), ('C0c0n179', 'AMPA'), ('C0c0n194', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n196', 'AMPA'), ('C0c0n210', 'AMPA'), ('C0c0n211', 'AMPA')]
# C0c2n226: [('C0c2n177', 'GABA_A'), ('C0c2n165', 'GABA_A'), ('C0c2n181', 'GABA_A'), ('C0c2n196', 'GABA_A'), ('C0c2n210', 'GABA_A'), ('C0c0n163', 'AMPA'), ('C0c0n165', 'AMPA'), ('C0c0n194', 'AMPA'), ('C0c0n196', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n210', 'AMPA'), ('C0c0n212', 'AMPA')]
# C0c2n195: [('C0c2n164', 'GABA_A'), ('C0c2n210', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n163', 'AMPA'), ('C0c0n178', 'AMPA'), ('C0c0n180', 'AMPA'), ('C0c0n181', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n196', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n210', 'AMPA')]
# C0c2n181: [('C0c2n165', 'GABA_A'), ('C0c2n195', 'GABA_A'), ('C0c0n165', 'AMPA'), ('C0c0n180', 'AMPA'), ('C0c0n181', 'AMPA'), ('C0c0n194', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n210', 'AMPA'), ('C0c0n212', 'AMPA'), ('C0c0n213', 'AMPA')]
# C0c2n209: [('C0c2n165', 'GABA_A'), ('C0c2n193', 'GABA_A'), ('C0c2n195', 'GABA_A'), ('C0c2n210', 'GABA_A'), ('C0c0n164', 'AMPA'), ('C0c0n179', 'AMPA'), ('C0c0n180', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n212', 'AMPA'), ('C0c0n213', 'AMPA')]
# C0c2n165: [('C0c2n178', 'GABA_A'), ('C0c2n194', 'GABA_A'), ('C0c2n196', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n181', 'AMPA'), ('C0c0n194', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n196', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n212', 'AMPA')]
# C0c2n161: [('C0c2n179', 'GABA_A'), ('C0c2n195', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n163', 'AMPA'), ('C0c0n164', 'AMPA'), ('C0c0n178', 'AMPA'), ('C0c0n181', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n210', 'AMPA'), ('C0c0n211', 'AMPA'), ('C0c0n212', 'AMPA'), ('C0c0n213', 'AMPA')]
# C0c2n213: [('C0c2n179', 'GABA_A'), ('C0c2n194', 'GABA_A'), ('C0c2n195', 'GABA_A'), ('C0c2n196', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n164', 'AMPA'), ('C0c0n165', 'AMPA'), ('C0c0n179', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n211', 'AMPA'), ('C0c0n212', 'AMPA'), ('C0c0n213', 'AMPA')]
# C0c2n178: [('C0c2n181', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n179', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n196', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n211', 'AMPA'), ('C0c0n212', 'AMPA'), ('C0c0n213', 'AMPA')]
# C0c2n211: [('C0c2n194', 'GABA_A'), ('C0c2n195', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n163', 'AMPA'), ('C0c0n164', 'AMPA'), ('C0c0n178', 'AMPA'), ('C0c0n211', 'AMPA'), ('C0c0n212', 'AMPA')]
# C0c2n193: [('C0c2n209', 'GABA_A'), ('C0c0n162', 'AMPA'), ('C0c0n163', 'AMPA'), ('C0c0n164', 'AMPA'), ('C0c0n194', 'AMPA'), ('C0c0n210', 'AMPA'), ('C0c0n211', 'AMPA'), ('C0c0n212', 'AMPA')]
# C0c2n218: [('C0c2n170', 'GABA_A'), ('C0c2n188', 'GABA_A'), ('C0c2n220', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n171', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n187', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n203', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n205', 'AMPA'), ('C0c0n218', 'AMPA'), ('C0c0n220', 'AMPA'), ('C0c0n221', 'AMPA')]
# C0c2n173: [('C0c2n171', 'GABA_A'), ('C0c2n188', 'GABA_A'), ('C0c2n204', 'GABA_A'), ('C0c2n220', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n171', 'AMPA'), ('C0c0n187', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n205', 'AMPA'), ('C0c0n220', 'AMPA'), ('C0c0n221', 'AMPA')]
# C0c2n186: [('C0c2n171', 'GABA_A'), ('C0c2n187', 'GABA_A'), ('C0c2n205', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n173', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n218', 'AMPA'), ('C0c0n219', 'AMPA'), ('C0c0n220', 'AMPA')]
# C0c2n189: [('C0c2n171', 'GABA_A'), ('C0c2n174', 'GABA_A'), ('C0c2n203', 'GABA_A'), ('C0c2n205', 'GABA_A'), ('C0c0n171', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n173', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n203', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n220', 'AMPA')]
# C0c2n219: [('C0c2n171', 'GABA_A'), ('C0c2n173', 'GABA_A'), ('C0c2n188', 'GABA_A'), ('C0c2n202', 'GABA_A'), ('C0c2n204', 'GABA_A'), ('C0c2n221', 'GABA_A'), ('C0c0n172', 'AMPA'), ('C0c0n173', 'AMPA'), ('C0c0n186', 'AMPA'), ('C0c0n187', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n218', 'AMPA'), ('C0c0n221', 'AMPA')]
# C0c2n203: [('C0c2n174', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n186', 'AMPA'), ('C0c0n187', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n205', 'AMPA'), ('C0c0n218', 'AMPA'), ('C0c0n221', 'AMPA')]
# C0c2n220: [('C0c2n186', 'GABA_A'), ('C0c2n221', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n171', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n173', 'AMPA'), ('C0c0n186', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n203', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n218', 'AMPA')]
# C0c2n170: [('C0c2n187', 'GABA_A'), ('C0c2n188', 'GABA_A'), ('C0c0n171', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n173', 'AMPA'), ('C0c0n186', 'AMPA'), ('C0c0n187', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n203', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n218', 'AMPA'), ('C0c0n220', 'AMPA')]
# C0c2n205: [('C0c2n187', 'GABA_A'), ('C0c2n189', 'GABA_A'), ('C0c2n202', 'GABA_A'), ('C0c2n203', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n171', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n203', 'AMPA'), ('C0c0n205', 'AMPA'), ('C0c0n220', 'AMPA')]
# C0c2n202: [('C0c2n189', 'GABA_A'), ('C0c2n204', 'GABA_A'), ('C0c2n219', 'GABA_A'), ('C0c0n171', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n203', 'AMPA')]
# C0c2n221: [('C0c2n189', 'GABA_A'), ('C0c2n202', 'GABA_A'), ('C0c2n219', 'GABA_A'), ('C0c2n220', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n171', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n186', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n219', 'AMPA'), ('C0c0n220', 'AMPA')]
# C0c2n174: [('C0c2n202', 'GABA_A'), ('C0c2n203', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n173', 'AMPA'), ('C0c0n187', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n203', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n219', 'AMPA')]
# C0c2n204: [('C0c2n203', 'GABA_A'), ('C0c0n186', 'AMPA'), ('C0c0n187', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n203', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n219', 'AMPA'), ('C0c0n220', 'AMPA'), ('C0c0n221', 'AMPA')]
# C0c2n171: [('C0c2n204', 'GABA_A'), ('C0c0n171', 'AMPA'), ('C0c0n172', 'AMPA'), ('C0c0n173', 'AMPA'), ('C0c0n187', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n218', 'AMPA'), ('C0c0n219', 'AMPA'), ('C0c0n220', 'AMPA'), ('C0c0n221', 'AMPA')]
# C0c2n187: [('C0c2n204', 'GABA_A'), ('C0c2n205', 'GABA_A'), ('C0c0n170', 'AMPA'), ('C0c0n186', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n202', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n218', 'AMPA'), ('C0c0n219', 'AMPA')]
# C0c2n44: [('C0c0n42', 'AMPA'), ('C0c0n29', 'AMPA'), ('C0c0n58', 'AMPA'), ('C0c0n59', 'AMPA'), ('C0c0n60', 'AMPA'), ('C0c0n61', 'AMPA'), ('C0c0n75', 'AMPA'), ('C0c0n76', 'AMPA'), ('C0c0n77', 'AMPA'), ('C0c0n90', 'AMPA')]
# C0c2n164: [('C0c0n162', 'AMPA'), ('C0c0n164', 'AMPA'), ('C0c0n178', 'AMPA'), ('C0c0n179', 'AMPA'), ('C0c0n194', 'AMPA'), ('C0c0n196', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n210', 'AMPA')]
# C0c2n210: [('C0c0n162', 'AMPA'), ('C0c0n163', 'AMPA'), ('C0c0n165', 'AMPA'), ('C0c0n178', 'AMPA'), ('C0c0n194', 'AMPA'), ('C0c0n195', 'AMPA'), ('C0c0n197', 'AMPA'), ('C0c0n210', 'AMPA')]
# C0c2n188: [('C0c0n170', 'AMPA'), ('C0c0n171', 'AMPA'), ('C0c0n173', 'AMPA'), ('C0c0n186', 'AMPA'), ('C0c0n188', 'AMPA'), ('C0c0n189', 'AMPA'), ('C0c0n203', 'AMPA'), ('C0c0n204', 'AMPA'), ('C0c0n219', 'AMPA')]
#
# New configuration applied to DYNAP-SE1!

# %%
ut.set_parameters_in_txt_file(model, 'subthreshold_params.txt')

# %%
# =============================================================================
# Program FPGA spike generators: dynamic reference phase shifting
# =============================================================================
# All four input channels run at the same frequency: 35 Hz.
#
#   Ch1 = 0 degrees
#   Ch2 = 90 degrees
#   Ch3 = 180 degrees
#   Ch4 = 270 degrees


# Stimulus duration, in seconds.
duration = 20.0

# Target chip for generated spikes.
post_chip = 0

# All channels and reference use the same rate.
validation_rate_hz = 35.0
period_s = 1.0 / validation_rate_hz

# Fixed input-channel phases.
# Ch1, Ch2, Ch3, Ch4
channel_phase_degrees = [0, 0.2, 0.2, 0.2]
channel_phase_offsets_s = [
    (phase_deg / 360.0) * period_s
    for phase_deg in channel_phase_degrees
]

print(f"Rate: {validation_rate_hz} Hz")
print(f"Period: {period_s * 1000:.3f} ms")

for ch_idx, (deg, offset_s) in enumerate(
    zip(channel_phase_degrees, channel_phase_offsets_s)
):
    print(f"Ch{ch_idx + 1}: {deg} degrees = {offset_s * 1000:.3f} ms")

# First four spike generators are the four channels.
fpga_ids = ut.get_global_id_list(spikegen_ids[:N_POPULATIONS])
print("Channel FPGA generator IDs:", fpga_ids)

# The fifth spike generator is used as a reference generator.
ref_fpga_id = ut.get_global_id_list(spikegen_ids)[N_POPULATIONS]
print("Reference generator FPGA ID:", ref_fpga_id)

# Switch the reference phase through all populations in sequence.
segment_len = duration / N_POPULATIONS

phase_segments = [
    (
        idx * segment_len,
        (idx + 1) * segment_len,
        channel_phase_offsets_s[idx],
    )
    for idx in range(N_POPULATIONS)
]

print("Reference phase segments:")
for idx, (seg_start, seg_stop, ref_phase_s) in enumerate(phase_segments):
    print(
        f"  {seg_start:.1f}-{seg_stop:.1f} s: "
        f"Ref matches Ch{idx + 1}, "
        f"phase = {channel_phase_degrees[idx]} degrees "
        f"({ref_phase_s * 1000:.3f} ms)"
    )

# FPGA controller.
fpga = model.get_fpga_spike_gen()

# Scheduled FPGA event containers.
all_times = []
all_indices = []
all_targets = []

# For plotting/debugging.
input_spike_times = {
    "Ch1": [],
    "Ch2": [],
    "Ch3": [],
    "Ch4": [],
    "Ref": [],
}

# Useful for later analysis.
correlated_channel_by_segment = list(range(N_POPULATIONS))

# -----------------------------------------------------------------------------
# Helper function
# -----------------------------------------------------------------------------
def make_periodic_times(rate_hz, start_s, stop_s, phase_s=0.0):
    """
    Periodic spike times between start_s and stop_s.

    Important:
    phase_s is measured relative to t=0, not relative to each segment.
    This keeps a globally consistent phase relationship.
    """
    period = 1.0 / rate_hz

    # First spike index whose time is >= start_s.
    first_k = int(np.ceil((start_s - phase_s) / period))
    if first_k < 0:
        first_k = 0

    times = phase_s + np.arange(first_k, first_k + 100000) * period
    times = times[(times >= start_s) & (times < stop_s)]

    return times

# -----------------------------------------------------------------------------
# Schedule fixed channel inputs for the full 20 seconds
# -----------------------------------------------------------------------------
for ch_idx, generator_id in enumerate(fpga_ids):
    ch_phase_s = channel_phase_offsets_s[ch_idx]

    ch_times = make_periodic_times(
        validation_rate_hz,
        0.0,
        duration,
        phase_s=ch_phase_s,
    )

    input_spike_times[f"Ch{ch_idx + 1}"].extend(ch_times)

    all_times.extend(ch_times)
    all_indices.extend([generator_id] * len(ch_times))
    all_targets.extend([post_chip] * len(ch_times))

# -----------------------------------------------------------------------------
# Schedule reference with changing phase
# -----------------------------------------------------------------------------
for seg_idx, (seg_start, seg_stop, ref_phase_s) in enumerate(phase_segments):
    ref_times = make_periodic_times(
        validation_rate_hz,
        seg_start,
        seg_stop,
        phase_s=ref_phase_s,
    )

    input_spike_times["Ref"].extend(ref_times)

    all_times.extend(ref_times)
    all_indices.extend([ref_fpga_id] * len(ref_times))
    all_targets.extend([post_chip] * len(ref_times))

# Convert debug lists to numpy arrays.
for key in input_spike_times:
    input_spike_times[key] = np.array(input_spike_times[key])

# -----------------------------------------------------------------------------
# Sort events before programming FPGA
# -----------------------------------------------------------------------------
if not all_times:
    raise ValueError("No spikes scheduled.")

sort_order = np.argsort(all_times)

all_times = np.array(all_times)[sort_order].tolist()
all_indices = np.array(all_indices)[sort_order].tolist()
all_targets = np.array(all_targets)[sort_order].tolist()

print("Total scheduled spikes:", len(all_times))
print("First 20 scheduled events:")
for t, idx in list(zip(all_times, all_indices))[:20]:
    print(f"  t={t:.6f} s, generator={idx}")

# -----------------------------------------------------------------------------
# Program FPGA
# -----------------------------------------------------------------------------
isi_base = 900
repeat_mode = True

ut.set_fpga_spike_gen(
    fpga,
    all_times,
    all_indices,
    all_targets,
    isi_base,
    repeat_mode,
)

print("FPGA programmed for dynamic reference phase-shift validation.")
# Out:
# Rate: 35.0 Hz
# Period: 28.571 ms
# Ch1: 0 degrees = 0.000 ms
# Ch2: 0.2 degrees = 0.016 ms
# Ch3: 0.2 degrees = 0.016 ms
# Ch4: 0.2 degrees = 0.016 ms
# Channel FPGA generator IDs: [271, 272, 273, 274]
# Reference generator FPGA ID: 275
# Reference phase segments:
#   0.0-5.0 s: Ref matches Ch1, phase = 0 degrees (0.000 ms)
#   5.0-10.0 s: Ref matches Ch2, phase = 0.2 degrees (0.016 ms)
#   10.0-15.0 s: Ref matches Ch3, phase = 0.2 degrees (0.016 ms)
#   15.0-20.0 s: Ref matches Ch4, phase = 0.2 degrees (0.016 ms)
# Total scheduled spikes: 3500
# First 20 scheduled events:
#   t=0.000000 s, generator=271
#   t=0.000000 s, generator=275
#   t=0.000016 s, generator=274
#   t=0.000016 s, generator=273
#   t=0.000016 s, generator=272
#   t=0.028571 s, generator=275
#   t=0.028571 s, generator=271
#   t=0.028587 s, generator=272
#   t=0.028587 s, generator=274
#   t=0.028587 s, generator=273
#   t=0.057143 s, generator=275
#   t=0.057143 s, generator=271
#   t=0.057159 s, generator=274
#   t=0.057159 s, generator=272
#   t=0.057159 s, generator=273
#   t=0.085714 s, generator=271
#   t=0.085714 s, generator=275
#   t=0.085730 s, generator=272
#   t=0.085730 s, generator=274
#   t=0.085730 s, generator=273
# VariableIsiMode already 1
# FPGA programmed for dynamic reference phase-shift validation.
# RepeatMode already 1

# %%
# =============================================================================
# 7. Run the network and collect events
# =============================================================================

# Total recorded duration.
D = duration

# Total population sizes used for normalization during plotting.
NI = sum(len(population) for population in inh_neuron_ids)
NE = sum(len(population) for population in exc_neuron_ids)


# Flatten all populations into one monitor list.
monitored_neurons = [
    neuron
    for population in exc_neuron_ids
    for neuron in population
] + [
    neuron
    for population in inh_neuron_ids
    for neuron in population
]


# Create and start a selective monitoring graph.
graph, filter_node, sink_node = ut.create_neuron_select_graph(model, monitored_neurons)
graph.start()

print("Monitored neurons:", monitored_neurons)
filter_node.set_neurons(monitored_neurons)

# Clear any stale events before starting the trial.
sink_node.get_events()
api.reset_timestamp()

# Start stimulus, wait for the stimulus duration, then stop the FPGA.
fpga.start()
time.sleep(duration)
fpga.stop()

# Keep recording for post-stimulus activity.
graph.stop()

# Retrieve recorded events from the sink node.
events = sink_node.get_events()
print(len(events), "events recorded.")

# Convert neuron ID tuples into chip-local neuron IDs for classification.
e_neuron_chip_ids = [nid[2] for population in exc_neuron_ids for nid in population if nid[0] == 0 and nid[1] == 0]
i_neuron_chip_ids = [nid[2] for population in inh_neuron_ids for nid in population if nid[0] == 0 and nid[1] == 0]

# Extract event times for both relevant cores
spike_t = []
spike_core = []
spike_id = []

for evt in events:
    if evt.chip_id == 0 and evt.core_id in (E_CORE_ID, I_CORE_ID):
        spike_t.append(evt.timestamp * 1e-6)
        spike_core.append(evt.core_id)
        spike_id.append(evt.neuron_id)

spike_t = np.array(spike_t)
spike_core = np.array(spike_core)
spike_id = np.array(spike_id)

# Since E neurons are on core 0 and I neurons on core 2 in this notebook
is_e_spike = spike_core == E_CORE_ID
is_i_spike = spike_core == I_CORE_ID

e_spike_t = spike_t[is_e_spike]
e_spike_id = spike_id[is_e_spike] + E_CORE_ID * 256
i_spike_t = spike_t[is_i_spike]
i_spike_id = spike_id[is_i_spike] + I_CORE_ID * 256

# -----------------------------------------------------------------------------
# Compute smoothed population-rate traces
# -----------------------------------------------------------------------------
fs = 200  # Sampling frequency for binned spike trains, in Hz.
n_bins = int(D * fs)

# Rows: 0 = excitatory population, 1 = inhibitory population
binPOP = np.zeros((2, n_bins))

for t in e_spike_t:
    if t < D:
        binPOP[0, int(t * fs)] = 1

for t in i_spike_t:
    if t < D:
        binPOP[1, int(t * fs)] = 1

# Smooth binned spikes with a Gaussian-like kernel.
sigma = 0.01
x = np.arange(int(-0.2 * fs), int(0.2 * fs)) / fs
gauss = np.exp(-(x ** 2) / sigma)

binPOP[0] = np.convolve(binPOP[0], gauss, 'same')
binPOP[1] = np.convolve(binPOP[1], gauss, 'same')
# Out:
# Monitored neurons: [(0, 0, 34), (0, 0, 35), (0, 0, 36), (0, 0, 37), (0, 0, 50), (0, 0, 51), (0, 0, 52), (0, 0, 53), (0, 0, 66), (0, 0, 67), (0, 0, 68), (0, 0, 69), (0, 0, 82), (0, 0, 83), (0, 0, 84), (0, 0, 85), (0, 0, 42), (0, 0, 43), (0, 0, 29), (0, 0, 45), (0, 0, 58), (0, 0, 59), (0, 0, 60), (0, 0, 61), (0, 0, 28), (0, 0, 75), (0, 0, 76), (0, 0, 77), (0, 0, 90), (0, 0, 91), (0, 0, 92), (0, 0, 93), (0, 0, 162), (0, 0, 163), (0, 0, 164), (0, 0, 165), (0, 0, 178), (0, 0, 179), (0, 0, 180), (0, 0, 181), (0, 0, 194), (0, 0, 195), (0, 0, 196), (0, 0, 197), (0, 0, 210), (0, 0, 211), (0, 0, 212), (0, 0, 213), (0, 0, 170), (0, 0, 171), (0, 0, 172), (0, 0, 173), (0, 0, 186), (0, 0, 187), (0, 0, 188), (0, 0, 189), (0, 0, 202), (0, 0, 203), (0, 0, 204), (0, 0, 205), (0, 0, 218), (0, 0, 219), (0, 0, 220), (0, 0, 221), (0, 2, 34), (0, 2, 18), (0, 2, 36), (0, 2, 37), (0, 2, 50), (0, 2, 51), (0, 2, 19), (0, 2, 53), (0, 2, 66), (0, 2, 67), (0, 2, 68), (0, 2, 69), (0, 2, 82), (0, 2, 83), (0, 2, 84), (0, 2, 21), (0, 2, 42), (0, 2, 43), (0, 2, 44), (0, 2, 45), (0, 2, 58), (0, 2, 59), (0, 2, 60), (0, 2, 61), (0, 2, 74), (0, 2, 75), (0, 2, 76), (0, 2, 77), (0, 2, 90), (0, 2, 91), (0, 2, 92), (0, 2, 94), (0, 2, 161), (0, 2, 177), (0, 2, 164), (0, 2, 165), (0, 2, 178), (0, 2, 179), (0, 2, 193), (0, 2, 181), (0, 2, 194), (0, 2, 195), (0, 2, 196), (0, 2, 209), (0, 2, 210), (0, 2, 211), (0, 2, 226), (0, 2, 213), (0, 2, 170), (0, 2, 171), (0, 2, 174), (0, 2, 173), (0, 2, 186), (0, 2, 187), (0, 2, 188), (0, 2, 189), (0, 2, 202), (0, 2, 203), (0, 2, 204), (0, 2, 205), (0, 2, 218), (0, 2, 219), (0, 2, 220), (0, 2, 221)]
# 8509 events recorded.

# %%
from collections import Counter, defaultdict
import numpy as np

# --- FIX: Account for both Excitatory (Core 0) and Inhibitory (Core 2) cores ---
stimulus_spikes_by_unit = Counter(
    (evt.chip_id, evt.core_id, evt.neuron_id)
    for evt in events
    if evt.chip_id == CHIP_ID 
    and evt.core_id in (E_CORE_ID, I_CORE_ID) 
    and (evt.timestamp * 1e-6 < duration)
)

# tracked populations (E1.., I1..)
tracked_populations = []
for pop_index, population in enumerate(exc_neuron_ids, start=1):
    tracked_populations.append(("E", pop_index, population))
for pop_index, population in enumerate(inh_neuron_ids, start=1):
    tracked_populations.append(("I", pop_index, population))

# build unit_rows (one dict per unit)
unit_rows = []
for population_label, population_index, population in tracked_populations:
    for unit_index, (chip_id, core_id, neuron_id) in enumerate(population):
        stim_spike_count = stimulus_spikes_by_unit.get((chip_id, core_id, neuron_id), 0)
        stim_rate_hz = stim_spike_count / duration if duration > 0 else 0.0
        unit_rows.append({
            "population": f"{population_label}{population_index}",
            "unit": unit_index,
            "chip_id": chip_id,
            "core_id": core_id,
            "neuron_id": neuron_id,
            "stim_spikes": stim_spike_count,
            "stim_rate_hz": stim_rate_hz,
        })

# Build per-population spike-count arrays
pop_counts = defaultdict(list)
for row in unit_rows:
    pop_counts[row["population"]].append(row["stim_spikes"])

# Compute per-population mean/std for active units
pop_stats = {}
for pop, counts in pop_counts.items():
    arr = np.array(counts, dtype=float)
    active = arr[arr > 0]
    if len(active) > 0:
        mean_active = float(active.mean())
        std_active = float(active.std())
    else:
        mean_active = 0.0
        std_active = 0.0
    pop_stats[pop] = (mean_active, std_active)

allowed_margin_std = 1.0

print("Per-population activity summary during the stimulus window:")
for pop, (mean_active, std_active) in pop_stats.items():
    print(f"{pop}: mean_active_spikes={mean_active:.2f} | std={std_active:.2f}")

print("\npopulation unit chip core neuron stim_spikes stim_rate_hz status")

shown_units = 0
for row in unit_rows:
    pop = row["population"]
    mean_active, std_active = pop_stats.get(pop, (0.0, 0.0))
    high_threshold = mean_active + allowed_margin_std * std_active

    if row["stim_spikes"] == 0:
        status = "silent"
    elif row["stim_spikes"] > high_threshold:
        status = "high"
    else:
        status = None

    if status is None:
        continue

    shown_units += 1
    print(
        f"{row['population']} {row['unit']:02d} {row['chip_id']} {row['core_id']} {row['neuron_id']}"
        f" {row['stim_spikes']} {row['stim_rate_hz']:.2f} {status}"
    )

print(f"\nShown units only: {shown_units} / {len(unit_rows)} total")
# Out:
# Per-population activity summary during the stimulus window:
# E1: mean_active_spikes=39.81 | std=2.46
# E2: mean_active_spikes=57.31 | std=18.11
# E3: mean_active_spikes=66.44 | std=11.03
# E4: mean_active_spikes=60.12 | std=15.69
# I1: mean_active_spikes=43.75 | std=1.35
# I2: mean_active_spikes=85.50 | std=5.65
# I3: mean_active_spikes=86.88 | std=8.64
# I4: mean_active_spikes=91.88 | std=7.72
#
# population unit chip core neuron stim_spikes stim_rate_hz status
# E1 04 0 0 50 44 2.20 high
# E1 06 0 0 52 43 2.15 high
# E1 07 0 0 53 43 2.15 high
# E1 08 0 0 66 43 2.15 high
# E2 04 0 0 58 80 4.00 high
# E2 08 0 0 28 78 3.90 high
# E2 10 0 0 76 87 4.35 high
# E3 09 0 0 195 81 4.05 high
# E3 11 0 0 197 84 4.20 high
# E4 03 0 0 173 77 3.85 high
# E4 09 0 0 203 76 3.80 high
# E4 13 0 0 219 79 3.95 high
# E4 14 0 0 220 77 3.85 high
# I1 00 0 2 34 46 2.30 high
# I1 04 0 2 50 46 2.30 high
# I1 15 0 2 21 46 2.30 high
# I2 07 0 2 61 93 4.65 high
# I2 10 0 2 76 93 4.65 high
# I2 11 0 2 77 93 4.65 high
# I3 02 0 2 164 104 5.20 high
# I3 09 0 2 195 100 5.00 high
# I3 15 0 2 213 96 4.80 high
# I4 02 0 2 174 100 5.00 high
# I4 04 0 2 186 100 5.00 high
# I4 14 0 2 220 106 5.30 high
#
# Shown units only: 25 / 128 total

# %%
# =============================================================================
# 8. Plot raster and population activity
# =============================================================================

# Initialize a single panel figure specifically for the stacked raster plot
fig, ax_raster = plt.subplots(figsize=(10, 6))

# Build lookup (chip,core,neuron) -> (label, pop_index, unit_index)
pop_map = {}
for pidx, pop in enumerate(exc_neuron_ids):
    for uidx, (chip, core, nid) in enumerate(pop):
        pop_map[(chip, core, nid)] = ("E", pidx, uidx)
for pidx, pop in enumerate(inh_neuron_ids):
    for uidx, (chip, core, nid) in enumerate(pop):
        pop_map[(chip, core, nid)] = ("I", pidx, uidx)

# Ordered populations and stacked baseline positions
pop_order = [("E", i) for i in range(len(exc_neuron_ids))] + [("I", i) for i in range(len(inh_neuron_ids))]
base_by_pop = {}
cum = 0
gap = 3
for label, pidx in pop_order:
    size = len(exc_neuron_ids[pidx]) if label == "E" else len(inh_neuron_ids[pidx])
    base_by_pop[(label, pidx)] = cum
    cum += size + gap

# Collect spikes per population (time, y)
from collections import defaultdict
plot_bins = defaultdict(lambda: {"t": [], "y": []})
for evt in events:
    key = (evt.chip_id, evt.core_id, evt.neuron_id)
    info = pop_map.get(key)
    if info is None:
        continue
    label, pidx, uidx = info
    base = base_by_pop[(label, pidx)]
    plot_bins[(label, pidx)]["t"].append(evt.timestamp * 1e-6)
    plot_bins[(label, pidx)]["y"].append(base + uidx)

# Color maps
colors_E = plt.cm.Blues(np.linspace(0.5, 1.0, max(1, len(exc_neuron_ids))))
colors_I = plt.cm.Reds(np.linspace(0.5, 1.0, max(1, len(inh_neuron_ids))))

# Plot onto ax_raster
for (label, pidx), data in plot_bins.items():
    if not data["t"]:
        continue
    c = colors_E[pidx % len(colors_E)] if label == "E" else colors_I[pidx % len(colors_I)]
    ax_raster.scatter(data["t"], data["y"], marker="|", c=[c], s=80, label=f"{label}{pidx+1}")

# Ticks/labels/limits
yticks = []
ylabels = []
for label, pidx in pop_order:
    base = base_by_pop[(label, pidx)]
    size = len(exc_neuron_ids[pidx]) if label == "E" else len(inh_neuron_ids[pidx])
    center = base + (size - 1) / 2
    yticks.append(center)
    ylabels.append(f"{label}{pidx+1}")

ax_raster.set_yticks(yticks)
ax_raster.set_yticklabels(ylabels)
ax_raster.set_xlabel("Time (s)")
ax_raster.set_ylabel("Population (centered units)")
ax_raster.set_xlim(0, D)
ax_raster.set_ylim(-1, cum)
#ax_raster.set_title("Raster — populations stacked (E: blue, I: red)")
ax_raster.legend(loc="upper right", ncol=2, fontsize="small")

plt.tight_layout()
plt.savefig('./figures/raster_phase_shift_180.svg')
plt.show()

# %%
# Code snippet to add a new cell for per-population rates
fs = 200  # Sampling frequency (Hz)
n_bins = int(D * fs)
time_axis = np.arange(n_bins) / fs

binned_E = np.zeros((N_POPULATIONS, n_bins))
binned_I = np.zeros((N_POPULATIONS, n_bins))

# Build unit-to-population maps for quick lookup
e_map = {unit: pidx for pidx, pop in enumerate(exc_neuron_ids) for unit in pop}
i_map = {unit: pidx for pidx, pop in enumerate(inh_neuron_ids) for unit in pop}

for evt in events:
    t = evt.timestamp * 1e-6
    if t >= D:
        continue
    key = (evt.chip_id, evt.core_id, evt.neuron_id)
    if key in e_map:
        binned_E[e_map[key], int(t * fs)] += 1
    elif key in i_map:
        binned_I[i_map[key], int(t * fs)] += 1

# Convert counts to actual firing rates (Hz) per neuron
bin_width = 1.0 / fs
for i in range(N_POPULATIONS):
    binned_E[i] /= (bin_width * len(exc_neuron_ids[i]))
    binned_I[i] /= (bin_width * len(inh_neuron_ids[i]))

# Smooth with a normalized Gaussian kernel
sigma = 0.01
x_kernel = np.arange(int(-0.2 * fs), int(0.2 * fs)) / fs
gauss = np.exp(-(x_kernel ** 2) / sigma)
gauss /= gauss.sum()  # Ensures firing rate scale is preserved

fig, axes = plt.subplots(N_POPULATIONS, 1, figsize=(12, 8), sharex=True)
for i in range(N_POPULATIONS):
    sm_E = np.convolve(binned_E[i], gauss, 'same')
    sm_I = np.convolve(binned_I[i], gauss, 'same')
    axes[i].plot(time_axis, sm_E, label=f'Exc Pop {i+1}', color='dodgerblue')
    axes[i].plot(time_axis, sm_I, label=f'Inh Pop {i+1}', color='crimson')
    axes[i].axvline(x=duration, color='black', linestyle=':', alpha=0.5, label='Stimulus End')
    axes[i].set_ylabel('Rate (Hz)')
    axes[i].legend(loc='upper right', fontsize='small')
    axes[i].set_title(f'Population {i+1} Dynamics')

axes[-1].set_xlabel('Time (s)')
plt.tight_layout()
plt.savefig('mean_rates_phase_shift_180.svg')
plt.show()

# %%
# =============================================================================
# New Section: Cross-Correlation Function (CCF) Analysis
# =============================================================================
import numpy as np
import matplotlib.pyplot as plt

# 1. Extract Reference Spike Train
ref_spikes = np.array([t for t, idx in zip(all_times, all_indices) if idx == ref_fpga_id])

# 2. Extract Spikes for each Excitatory Population
exc_pop_spikes = {i: [] for i in range(N_POPULATIONS)}
for evt in events:
    key = (evt.chip_id, evt.core_id, evt.neuron_id)
    if key in pop_map:
        label, pidx, uidx = pop_map[key]
        if label == "E":
            exc_pop_spikes[pidx].append(evt.timestamp * 1e-6)

for i in range(N_POPULATIONS):
    exc_pop_spikes[i] = np.array(exc_pop_spikes[i])

# -----------------------------------------------------------------------------
# Function to Compute Spike-Time Cross-Correlogram (CCH)
# -----------------------------------------------------------------------------
def compute_spike_cch(ref, target, max_lag=0.1, bin_width=0.002):
    if len(ref) == 0 or len(target) == 0:
        bins = np.arange(-max_lag, max_lag + bin_width, bin_width)
        return np.zeros(len(bins) - 1), bins
    
    ref_sorted = np.sort(ref)
    target_sorted = np.sort(target)
    
    diffs = []
    # Efficient windowed search for pairwise time differences
    for r_t in ref_sorted:
        idx_start = np.searchsorted(target_sorted, r_t - max_lag)
        idx_end = np.searchsorted(target_sorted, r_t + max_lag)
        for t_t in target_sorted[idx_start:idx_end]:
            diffs.append(t_t - r_t)
            
    bins = np.arange(-max_lag, max_lag + bin_width, bin_width)
    counts, _ = np.histogram(diffs, bins=bins)
    
    # Normalize to Coincidence Rate (Hz) = counts / (N_ref * bin_width)
    coincidence_rate = counts / (len(ref) * bin_width)
    return coincidence_rate, bins

# -----------------------------------------------------------------------------
# Plotting the Results
# -----------------------------------------------------------------------------
# Create a 2x4 multi-panel figure for all 4 populations
fig, axes = plt.subplots(2, N_POPULATIONS, figsize=(20, 8), sharex='row')

colors = plt.cm.Blues(np.linspace(0.6, 1.0, N_POPULATIONS))
max_lag_seconds = 0.1
bin_sz = 0.002

# --- Row 1: High-Resolution Spike-Time CCH ---
for i in range(N_POPULATIONS):
    ax = axes[0, i]
    cch, bins = compute_spike_cch(ref_spikes, exc_pop_spikes[i], max_lag=max_lag_seconds, bin_width=bin_sz)
    bin_centers = bins[:-1] + bin_sz / 2
    
    ax.bar(bin_centers, cch, width=bin_sz, color=colors[i], edgecolor='none', alpha=0.85)
    ax.axvline(0, color='gray', linestyle='--', alpha=0.7)
    ax.set_title(f'Pop E{i+1} Spike-Time CCH')
    if i == 0:
        ax.set_ylabel('Coincidence Rate (Hz)')
    ax.set_xlabel('Time Lag $\\tau$ (s)')
    ax.grid(True, alpha=0.2)

# --- Row 2: Macro-Scale Firing Rate CCF ---
# Re-bin the data globally to do a standard normalized signal cross-correlation
fs_ccf = 100
n_bins_ccf = int(D * fs_ccf)
lags_to_check = int(5 * fs_ccf)  # check lags up to +/- 5 seconds

ref_binned = np.zeros(n_bins_ccf)
for t in ref_spikes:
    if t < D: ref_binned[int(t * fs_ccf)] += 1

for i in range(N_POPULATIONS):
    ax = axes[1, i]
    pop_binned = np.zeros(n_bins_ccf)
    for t in exc_pop_spikes[i]:
        if t < D: pop_binned[int(t * fs_ccf)] += 1
        
    # Subtract mean to evaluate covariance/correlation
    ref_centered = ref_binned - np.mean(ref_binned)
    pop_centered = pop_binned - np.mean(pop_binned)
    
    # Compute cross-correlation profile
    ccf_signal = np.correlate(pop_centered, ref_centered, mode='same')
    
    # Normalize by auto-correlation at zero lag to obtain coefficients between -1 and 1
    norm_factor = np.sqrt(np.sum(ref_centered**2) * np.sum(pop_centered**2))
    if norm_factor > 0:
        ccf_signal = ccf_signal / norm_factor
        
    # Extract the center window corresponding to our lag range
    center_idx = len(ccf_signal) // 2
    display_ccf = ccf_signal[center_idx - lags_to_check : center_idx + lags_to_check]
    lag_axis = np.arange(-lags_to_check, lags_to_check) / fs_ccf
    
    ax.plot(lag_axis, display_ccf, color=colors[i], lw=2)
    ax.axvline(0, color='gray', linestyle='--', alpha=0.7)
    ax.set_title(f'Pop E{i+1} Rate Tracking CCF')
    if i == 0:
        ax.set_ylabel('Cross-Correlation Coeff.')
    ax.set_xlabel('Time Lag $\\tau$ (s)')
    ax.grid(True, alpha=0.2)

plt.tight_layout()
#plt.savefig('network_ccf_analysis.png', dpi=300)
plt.show()

# %%
# =============================================================================
# Validate which excitatory population is winning vs the reference
# =============================================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------------------------------------------------------
# Parameters for validation
# -----------------------------------------------------------------------------
segment_duration = duration / N_POPULATIONS
windows = [
    (i * segment_duration, (i + 1) * segment_duration)
    for i in range(N_POPULATIONS)
]

# A winner is considered strong if:
#   1. it is at least this many times larger than the average rest activity
#   2. its selectivity index is at least this large
#   3. its z-score against the rest is at least this large
ratio_threshold = 1.5
selectivity_threshold = 0.20
z_threshold = 2.0

# Plot style matched to the previous notebook plots.
colors_E = plt.cm.Blues(np.linspace(0.5, 1.0, max(1, N_POPULATIONS)))

# -----------------------------------------------------------------------------
# Build mapping from recorded neuron tuple to excitatory population
# -----------------------------------------------------------------------------
neuron_to_epop = {}

for pop_idx, population in enumerate(exc_neuron_ids, start=1):
    for chip_id, core_id, neuron_id in population:
        neuron_to_epop[(chip_id, core_id, neuron_id)] = pop_idx

# -----------------------------------------------------------------------------
# Convert events into excitatory spike table
# -----------------------------------------------------------------------------
e_spike_times_by_pop = {
    pop_idx: []
    for pop_idx in range(1, N_POPULATIONS + 1)
}

for evt in events:
    key = (evt.chip_id, evt.core_id, evt.neuron_id)

    if key in neuron_to_epop:
        pop_idx = neuron_to_epop[key]
        t_s = evt.timestamp * 1e-6
        e_spike_times_by_pop[pop_idx].append(t_s)

for pop_idx in e_spike_times_by_pop:
    e_spike_times_by_pop[pop_idx] = np.array(e_spike_times_by_pop[pop_idx])

# -----------------------------------------------------------------------------
# Validate each reference segment
# -----------------------------------------------------------------------------
rows = []

print("=" * 100)
print("Excitatory population winner validation")
print("=" * 100)
print(
    f"{'Window':<12} | "
    f"{'Expected':<10} | "
    f"{'Winner':<8} | "
    f"{'Rates Hz [E1,E2,E3,E4]':<35} | "
    f"{'Ratio':<7} | "
    f"{'SI':<7} | "
    f"{'z':<7} | "
    f"Decision"
)
print("-" * 100)

for seg_idx, (start_t, end_t) in enumerate(windows):
    expected_pop = seg_idx + 1
    window_len = end_t - start_t

    rates = {}

    for pop_idx in range(1, N_POPULATIONS + 1):
        spike_times = e_spike_times_by_pop[pop_idx]

        n_spikes = np.sum(
            (spike_times >= start_t)
            & (spike_times < end_t)
        )

        n_neurons = len(exc_neuron_ids[pop_idx - 1])

        # Mean firing rate per neuron in this population.
        rate_hz = n_spikes / (n_neurons * window_len)
        rates[pop_idx] = rate_hz

    # Actual winner = population with highest mean firing rate.
    winner_pop = max(rates, key=rates.get)
    winner_rate = rates[winner_pop]

    # Rest = all non-winning populations.
    rest_rates = np.array([
        rate
        for pop_idx, rate in rates.items()
        if pop_idx != winner_pop
    ])

    rest_mean = np.mean(rest_rates)
    rest_std = np.std(rest_rates, ddof=1) if len(rest_rates) > 1 else 0.0

    # Ratio: winner divided by average of rest.
    ratio = winner_rate / (rest_mean + 1e-9)

    # Selectivity index:
    # SI = 0 means winner and rest are equal.
    # SI close to 1 means winner is much larger.
    selectivity_index = (
        (winner_rate - rest_mean)
        / (winner_rate + rest_mean + 1e-9)
    )

    # z-score of winner relative to the rest populations.
    z_score = (
        (winner_rate - rest_mean)
        / (rest_std + 1e-9)
    )

    correct_winner = winner_pop == expected_pop
    significantly_bigger = (
        (ratio >= ratio_threshold)
        and (selectivity_index >= selectivity_threshold)
        and (z_score >= z_threshold)
    )

    if correct_winner and significantly_bigger:
        decision = "PASS"
    elif correct_winner:
        decision = "correct but weak"
    else:
        decision = "FAIL"

    rates_list = [
        rates[pop_idx]
        for pop_idx in range(1, N_POPULATIONS + 1)
    ]

    print(
        f"{start_t:>4.1f}-{end_t:<4.1f}s | "
        f"E_pop {expected_pop:<4} | "
        f"E_pop {winner_pop:<2} | "
        f"{np.round(rates_list, 2)}".ljust(35)
        + f" | {ratio:>5.2f} | "
        f"{selectivity_index:>5.2f} | "
        f"{z_score:>5.2f} | "
        f"{decision}"
    )

    rows.append({
        "segment": seg_idx + 1,
        "start_s": start_t,
        "end_s": end_t,
        "expected_pop": expected_pop,
        "winner_pop": winner_pop,
        "winner_rate_hz": winner_rate,
        "rest_mean_rate_hz": rest_mean,
        "rest_std_rate_hz": rest_std,
        "winner_to_rest_ratio": ratio,
        "selectivity_index": selectivity_index,
        "z_score_vs_rest": z_score,
        "correct_winner": correct_winner,
        "significantly_bigger": significantly_bigger,
        "decision": decision,
        "E1_rate_hz": rates[1],
        "E2_rate_hz": rates[2],
        "E3_rate_hz": rates[3],
        "E4_rate_hz": rates[4],
    })

print("=" * 100)

validation_df = pd.DataFrame(rows)
display(validation_df)

# -----------------------------------------------------------------------------
# Plot rates per segment
# -----------------------------------------------------------------------------
fig, ax = plt.subplots(figsize=(10, 4))

x = np.arange(1, N_POPULATIONS + 1)
segment_labels = [
    f"{int(row.start_s)}-{int(row.end_s)} s"
    for _, row in validation_df.iterrows()
]

for pop_idx in range(1, N_POPULATIONS + 1):
    ax.plot(
        x,
        validation_df[f"E{pop_idx}_rate_hz"],
        marker="o",
        color=colors_E[(pop_idx - 1) % len(colors_E)],
        label=f"E{pop_idx}",
    )

# Mark the expected winner in each segment using the same blue palette.
for seg_idx, expected_pop in enumerate(validation_df["expected_pop"], start=1):
    expected_rate = validation_df.loc[
        validation_df["segment"] == seg_idx,
        f"E{expected_pop}_rate_hz",
    ].iloc[0]
    ax.scatter(
        seg_idx,
        expected_rate,
        s=100,
        facecolors="none",
        edgecolors=[colors_E[(expected_pop - 1) % len(colors_E)]],
        linewidths=2,
        zorder=5,
    )

ax.set_xticks(x)
ax.set_xticklabels(segment_labels)
ax.set_xlabel("Reference phase segment")
ax.set_ylabel("Mean firing rate per neuron (Hz)")
ax.set_title("Excitatory population activity vs reference phase")
ax.grid(True, alpha=0.2)
ax.legend(loc="upper right", ncol=2, fontsize="small")
plt.tight_layout()
plt.savefig('./figures/phase_shift_winner_180.svg')
plt.show()

# -----------------------------------------------------------------------------
# Plot selectivity index per segment
# -----------------------------------------------------------------------------
fig, ax = plt.subplots(figsize=(8, 3))

bar_colors = [
    colors_E[(int(pop_idx) - 1) % len(colors_E)]
    for pop_idx in validation_df["winner_pop"]
]

ax.bar(
    validation_df["segment"],
    validation_df["selectivity_index"],
    color=bar_colors,
    edgecolor="none",
    alpha=0.85,
)

ax.axhline(
    selectivity_threshold,
    color="gray",
    linestyle="--",
    alpha=0.7,
    label=f"SI threshold = {selectivity_threshold}",
)

ax.set_xticks(validation_df["segment"])
ax.set_xticklabels(segment_labels)
ax.set_xlabel("Reference phase segment")
ax.set_ylabel("Selectivity index")
ax.set_title("Winner selectivity per segment")
ax.grid(True, axis="y", alpha=0.2)
ax.legend(loc="upper right", fontsize="small")
plt.tight_layout()
plt.savefig('./figures/selectivity_index_180.svg')
plt.show()
# Out:
# ====================================================================================================
# Excitatory population winner validation
# ====================================================================================================
# Window       | Expected   | Winner   | Rates Hz [E1,E2,E3,E4]              | Ratio   | SI      | z       | Decision
# ----------------------------------------------------------------------------------------------------
#  0.0-5.0 s | E_pop 1    | E_pop 1  | [11.78  0.    0.    0.  ] | 11775000000.00 |  1.00 | 11775000000.00 | PASS
#  5.0-10.0s | E_pop 2    | E_pop 3  | [0.02 4.58 5.56 5.09] |  1.72 |  0.27 |  0.84 | FAIL
# 10.0-15.0s | E_pop 3    | E_pop 3  | [0.   3.42 4.32 3.75] |  1.81 |  0.29 |  0.93 | correct but weak
# 15.0-20.0s | E_pop 4    | E_pop 3  | [0.   4.01 4.68 4.42] |  1.66 |  0.25 |  0.76 | FAIL
# ====================================================================================================
#    segment  start_s  end_s  expected_pop  winner_pop  winner_rate_hz  \
# 0        1      0.0    5.0             1           1         11.7750
# 1        2      5.0   10.0             2           3          5.5625
# 2        3     10.0   15.0             3           3          4.3250
# 3        4     15.0   20.0             4           3          4.6750
#
#    rest_mean_rate_hz  rest_std_rate_hz  winner_to_rest_ratio  \
# 0           0.000000          0.000000          1.177500e+10
# 1           3.229167          2.786696          1.722581e+00
# 2           2.391667          2.077609          1.808362e+00
# 3           2.812500          2.444413          1.662222e+00
#
#    selectivity_index  z_score_vs_rest  correct_winner  significantly_bigger  \
# 0           1.000000     1.177500e+10            True                  True
# 1           0.265403     8.373116e-01           False                 False
# 2           0.287841     9.305570e-01            True                 False
# 3           0.248748     7.619415e-01           False                 False
#
#            decision  E1_rate_hz  E2_rate_hz  E3_rate_hz  E4_rate_hz
# 0              PASS      11.775      0.0000      0.0000      0.0000
# 1              FAIL       0.025      4.5750      5.5625      5.0875
# 2  correct but weak       0.000      3.4250      4.3250      3.7500
# 3              FAIL       0.000      4.0125      4.6750      4.4250

# %% [markdown]
# ## Parameter reference notes
#
# The original final cell contained scratch code and unfinished debug snippets. It has been converted into notes so it will not accidentally run with undefined variables.
#
# Useful parameter examples:
#
# | Purpose | Parameter | Example `(coarse, fine)` |
# |---|---:|---:|
# | Threshold / neuron gain | `IF_THR_N` | `(6, 40)` |
# | Refractory period | `IF_RFR_N` | `(3, 50)` |
# | Leak / membrane time constant | `IF_TAU1_N` | `(5, 170)` |
# | Secondary leak term | `IF_TAU2_N` | `(0, 0)` |
# | DC current | `IF_DC_P` | `(0, 0)` |
# | Fast excitatory AMPA tau | `NPDPIE_TAU_F_P` | `(4, 80)` |
# | Fast excitatory AMPA threshold | `NPDPIE_THR_F_P` | `(0, 0)` |
# | Fast excitatory AMPA weight | `PS_WEIGHT_EXC_F_N` | `(0, 0)` |
# | Slow excitatory NMDA tau | `NPDPIE_TAU_S_P` | `(4, 80)` |
# | Slow excitatory NMDA threshold | `NPDPIE_THR_S_P` | `(0, 0)` |
# | Slow excitatory NMDA weight | `PS_WEIGHT_EXC_S_N` | `(0, 0)` |
# | NMDA neuron parameter | `IF_NMDA_N` | `(6, 148)` |
# | Fast inhibitory GABA_A tau | `NPDPII_TAU_F_P` | `(4, 80)` |
#
# Suggested debug checks, if needed later:
#
# ```python
# all_event_neuron_ids = [evt.neuron_id for evt in events]
# all_event_chip_ids = [evt.chip_id for evt in events]
# all_event_core_ids = [evt.core_id for evt in events]
#
# print("All unique neuron IDs in events:", sorted(set(all_event_neuron_ids)))
# print("Chips present:", sorted(set(all_event_chip_ids)))
# print("Cores present:", sorted(set(all_event_core_ids)))
# ```
